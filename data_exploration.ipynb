# %% [markdown]
# # Data exploration notebook

# %% [markdown]
# **This is for the Jupyter RR workshop data exploration lesson.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load in the data

# %%
gapminder = pd.read_table("../data/gapminderDataFiveYear_superDirty.txt", sep = "\t")

# %%
gapminder
# Out:
#         year         pop  life Exp    gdpPercap            region
# 0     1952.0   8425333.0    28.801   779.445314  Asia_Afghanistan
# 1     1957.0   9240934.0    30.332   820.853030  Asia_Afghanistan
# 2     1957.0   9240934.0    30.332   820.853030  Asia_Afghanistan
# 3     1962.0  10267083.0    31.997   853.100710  Asia_Afghanistan
# 4     1962.0         NaN    31.997          NaN  Asia_Afghanistan
# 5     1967.0  11537966.0    34.020   836.197138  Asia_Afghanistan
# 6     1972.0  13079460.0    36.088   739.981106  Asia_Afghanistan
# 7     1977.0  14880372.0    38.438   786.113360  Asia_Afghanistan
# 8     1982.0  12881816.0    39.854   978.011439  Asia_Afghanistan
# 9     1987.0  13867957.0    40.822   852.395945  Asia_Afghanistan
# 10    1992.0  16317921.0    41.674   649.341395  Asia_Afghanistan
# 11    1997.0  22227415.0    41.763   635.341351  Asia_Afghanistan
# 12    2002.0  25268405.0    42.129   726.734055  Asia_Afghanistan
# ...

# %%
gapminder.head()
# Out:
#      year         pop  life Exp   gdpPercap            region
# 0  1952.0   8425333.0    28.801  779.445314  Asia_Afghanistan
# 1  1957.0   9240934.0    30.332  820.853030  Asia_Afghanistan
# 2  1957.0   9240934.0    30.332  820.853030  Asia_Afghanistan
# 3  1962.0  10267083.0    31.997  853.100710  Asia_Afghanistan
# 4  1962.0         NaN    31.997         NaN  Asia_Afghanistan

# %%
gapminder.tail()
# Out:
#         year         pop  life Exp   gdpPercap           region
# 1715  1987.0   9216418.0    62.351  706.157306  Africa_Zimbabwe
# 1716  1992.0  10704340.0    60.377  693.420786  Africa_Zimbabwe
# 1717  1997.0  11404948.0    46.809  792.449960  Africa_Zimbabwe
# 1718  2002.0  11926563.0    39.989  672.038623  Africa_Zimbabwe
# 1719  2007.0  12311143.0    43.487  469.709298  Africa_Zimbabwe

# %%
gapminder.columns.values
# Out:
# array(['year', 'pop', 'life Exp', 'gdpPercap', 'region'], dtype=object)

# %%
gapminder.shape
# Out:
# (1720, 5)

# %%
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1720 entries, 0 to 1719
# Data columns (total 5 columns):
# year         1717 non-null float64
# pop          1715 non-null float64
# life Exp     1719 non-null float64
# gdpPercap    1718 non-null float64
# region       1720 non-null object
# dtypes: float64(4), object(1)
# memory usage: 67.3+ KB

# %%
gapminder.describe()
# Out:
#               year           pop     life Exp      gdpPercap
# count  1717.000000  1.715000e+03  1719.000000    1718.000000
# mean   1979.449039  2.954973e+07    59.436493    7208.452200
# std      17.228189  1.058366e+08    12.931041    9838.590984
# min    1952.000000  6.001100e+04    23.599000     241.165877
# 25%    1967.000000  2.807799e+06    48.143000    1203.161887
# 50%    1977.000000  7.026113e+06    60.523000    3529.585686
# 75%    1992.000000  1.959366e+07    70.840500    9322.285886
# max    2007.000000  1.318683e+09    82.603000  113523.132900

# %%
gapminder[['pop', 'life Exp', 'gdpPercap']].describe()
# Out:
#                 pop     life Exp      gdpPercap
# count  1.715000e+03  1719.000000    1718.000000
# mean   2.954973e+07    59.436493    7208.452200
# std    1.058366e+08    12.931041    9838.590984
# min    6.001100e+04    23.599000     241.165877
# 25%    2.807799e+06    48.143000    1203.161887
# 50%    7.026113e+06    60.523000    3529.585686
# 75%    1.959366e+07    70.840500    9322.285886
# max    1.318683e+09    82.603000  113523.132900

# %%
print(gapminder['life Exp'].min())
print(gapminder['life Exp'].max())
# Out:
# 23.599
# 82.603

# %%
# get a list of the unique regions
gapminder['region'].unique()
# Out:
# array(['Asia_Afghanistan', 'Europe_Albania', 'Africa_Algeria',
#        'Africa_Angola', 'Americas_Argentina', 'Oceania_Australia',
#        'Europe_Austria', 'Asia_Bahrain', 'Asia_Bangladesh',
#        'Europe_Belgium', 'Africa_Benin', 'Americas_Bolivia',
#        'Europe_Bosnia and Herzegovina', 'Africa_Botswana',
#        'Americas_Brazil', 'Europe_Bulgaria', 'Africa_Burkina Faso',
#        'Africa_Burundi', 'Asia_Cambodia', 'Africa_Cameroon', '_Canada',
#        'Americas_Canada', 'Africa_Central African Republic',
#        'Africa_Central african republic', 'Africa_Chad', 'Americas_Chile',
#        'Asia_China', 'Asia_china', 'Americas_Colombia',
#        'Americas_Colombia    ', 'Africa_Comoros',
#        'Africa_Congo, Dem. Rep.',
#        'Africa_Democratic Republic of the Congo',
#        'Africa_Congo, Democratic Republic', 'Africa_Congo, Rep.',
#        'Americas_Costa Rica', "Africa_Cote d'Ivoire",
#        "Africa_Cote d'Ivore", 'Europe_Croatia', 'Americas_Cuba',
# ...

# %%
print(len(gapminder['region'].unique()))
# Out:
# 151

# %%
#How many times does each unique region occur?
gapminder['region'].value_counts()
# Out:
# Europe_Netherlands                         15
# Americas_Bolivia                           14
# Asia_Afghanistan                           14
# Americas_Dominican Republic                14
# Africa_Nigeria                             13
# Africa_Algeria                             13
# Africa_Burundi                             13
# Asia_West Bank and Gaza                    13
# Americas_Argentina                         13
# Asia_Bangladesh                            13
# Europe_Turkey                              12
# Africa_Gabon                               12
# Africa_Ghana                               12
# Africa_Egypt                               12
# Asia_Vietnam                               12
# Europe_Poland                              12
# Europe_Czech Republic                      12
# Asia_Myanmar                               12
# Asia_Philippines                           12
# Asia_Bahrain                               12
# ...

# %%
for region in gapminder['region']:
    if gapminder[region].value_counts() < 2:
        print(gapminder['region'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Asia_Afghanistan'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-68edb2ec92d9> in <module>()
#       1 for region in gapminder['region']:
# ...

# %%
gapminder.head()
# Out:
#      year         pop  life Exp   gdpPercap            region
# 0  1952.0   8425333.0    28.801  779.445314  Asia_Afghanistan
# 1  1957.0   9240934.0    30.332  820.853030  Asia_Afghanistan
# 2  1957.0   9240934.0    30.332  820.853030  Asia_Afghanistan
# 3  1962.0  10267083.0    31.997  853.100710  Asia_Afghanistan
# 4  1962.0         NaN    31.997         NaN  Asia_Afghanistan

# %%
gapminder['year'].unique()
# Out:
# array([ 1952.,  1957.,  1962.,  1967.,  1972.,  1977.,  1982.,  1987.,
#         1992.,  1997.,  2002.,  2007.,    nan])

# %%
gapminder['year'].value_counts()
# Out:
# 1967.0    146
# 1977.0    145
# 1982.0    144
# 1972.0    143
# 1962.0    143
# 1992.0    143
# 1957.0    143
# 1987.0    142
# 1997.0    142
# 2007.0    142
# 2002.0    142
# 1952.0    142
# Name: year, dtype: int64

# %%
gapminder['year'].describe(include='2002')
# Out:
# count    1717.000000
# mean     1979.449039
# std        17.228189
# min      1952.000000
# 25%      1967.000000
# 50%      1977.000000
# 75%      1992.000000
# max      2007.000000
# Name: year, dtype: float64

# %%
gapminder[gapminder['year'] == 2002].describe()
# Out:
#          year           pop    life Exp     gdpPercap
# count   142.0  1.420000e+02  142.000000    142.000000
# mean   2002.0  4.145759e+07   65.694923   9917.848365
# std       0.0  1.408483e+08   12.279823  11154.114865
# min    2002.0  1.703720e+05   39.193000    241.165877
# 25%    2002.0  4.173506e+06   55.522250   1409.567264
# 50%    2002.0  1.037292e+07   70.825500   5319.804524
# 75%    2002.0  2.654556e+07   75.459250  13359.512257
# max    2002.0  1.280400e+09   82.000000  44683.975250

# %%
gapminder[gapminder['year'] == 2002]['life Exp'].describe()
# Out:
# count    142.000000
# mean      65.694923
# std       12.279823
# min       39.193000
# 25%       55.522250
# 50%       70.825500
# 75%       75.459250
# max       82.000000
# Name: life Exp, dtype: float64

# %%
# make a copy of our dataframe to work with for data cleaning

# %%
gapminder_copy = gapminder.copy()

# %%
gapminder_copy.head()
# Out:
#      year         pop  life Exp   gdpPercap            region
# 0  1952.0   8425333.0    28.801  779.445314  Asia_Afghanistan
# 1  1957.0   9240934.0    30.332  820.853030  Asia_Afghanistan
# 2  1957.0   9240934.0    30.332  820.853030  Asia_Afghanistan
# 3  1962.0  10267083.0    31.997  853.100710  Asia_Afghanistan
# 4  1962.0         NaN    31.997         NaN  Asia_Afghanistan

# %%
#remove NAs from data frame (physically removes those rows)
gapminder_copy = gapminder_copy.dropna()
gapminder_copy.head()
# Out:
#      year         pop  life Exp   gdpPercap            region
# 0  1952.0   8425333.0    28.801  779.445314  Asia_Afghanistan
# 1  1957.0   9240934.0    30.332  820.853030  Asia_Afghanistan
# 2  1957.0   9240934.0    30.332  820.853030  Asia_Afghanistan
# 3  1962.0  10267083.0    31.997  853.100710  Asia_Afghanistan
# 5  1967.0  11537966.0    34.020  836.197138  Asia_Afghanistan

# %%
gapminder_copy.shape
# Out:
# (1712, 5)

# %%
gapminder_copy['year'] = gapminder_copy['year'].astype(int)

# %%
gapminder_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1712 entries, 0 to 1719
# Data columns (total 5 columns):
# year         1712 non-null int32
# pop          1712 non-null float64
# life Exp     1712 non-null float64
# gdpPercap    1712 non-null float64
# region       1712 non-null object
# dtypes: float64(3), int32(1), object(1)
# memory usage: 73.6+ KB

# %%
gapminder_copy['pop'] = gapminder_copy['pop'].astype(int)

# %%
gapminder_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1712 entries, 0 to 1719
# Data columns (total 5 columns):
# year         1712 non-null int32
# pop          1712 non-null int32
# life Exp     1712 non-null float64
# gdpPercap    1712 non-null float64
# region       1712 non-null object
# dtypes: float64(2), int32(2), object(1)
# memory usage: 66.9+ KB

# %%
gapminder_copy[0:15]
# Out:
#     year       pop  life Exp    gdpPercap            region
# 0   1952   8425333    28.801   779.445314  Asia_Afghanistan
# 1   1957   9240934    30.332   820.853030  Asia_Afghanistan
# 2   1957   9240934    30.332   820.853030  Asia_Afghanistan
# 3   1962  10267083    31.997   853.100710  Asia_Afghanistan
# 5   1967  11537966    34.020   836.197138  Asia_Afghanistan
# 6   1972  13079460    36.088   739.981106  Asia_Afghanistan
# 7   1977  14880372    38.438   786.113360  Asia_Afghanistan
# 8   1982  12881816    39.854   978.011439  Asia_Afghanistan
# 9   1987  13867957    40.822   852.395945  Asia_Afghanistan
# 10  1992  16317921    41.674   649.341395  Asia_Afghanistan
# 11  1997  22227415    41.763   635.341351  Asia_Afghanistan
# 12  2002  25268405    42.129   726.734055  Asia_Afghanistan
# 13  2007  31889923    43.828   974.580338  Asia_Afghanistan
# 14  1952   1282697    55.230  1601.056136    Europe_Albania
# 15  1957   1476505    59.280  1942.284244    Europe_Albania

# %%
gapminder_copy[-10:]
# Out:
#       year       pop  life Exp   gdpPercap           region
# 1710  1962   4277736    52.358  527.272182  Africa_Zimbabwe
# 1711  1967   4995432    53.995  569.795071  Africa_Zimbabwe
# 1712  1972   5861135    55.635  799.362176  Africa_Zimbabwe
# 1713  1977   6642107    57.674  685.587682  Africa_Zimbabwe
# 1714  1982   7636524    60.363  788.855041  Africa_Zimbabwe
# 1715  1987   9216418    62.351  706.157306  Africa_Zimbabwe
# 1716  1992  10704340    60.377  693.420786  Africa_Zimbabwe
# 1717  1997  11404948    46.809  792.449960  Africa_Zimbabwe
# 1718  2002  11926563    39.989  672.038623  Africa_Zimbabwe
# 1719  2007  12311143    43.487  469.709298  Africa_Zimbabwe

# %%
gapminder_copy.sort_values(by='year', ascending=False)
# Out:
#       year        pop  life Exp     gdpPercap                         region
# 1719  2007   12311143    43.487    469.709298                Africa_Zimbabwe
# 850   2007   23301725    67.297   1593.065480          Asia_Korea, Dem. Rep.
# 946   2007   13327079    48.303    759.349910                  Africa_Malawi
# 934   2007   19167654    59.443   1044.770126              Africa_Madagascar
# 922   2007    6036914    73.952  12057.499280                   Africa_Libya
# 150   2007    9119152    65.554   3822.137084               Americas_Bolivia
# 910   2007    3193942    45.678    414.507341                 Africa_Liberia
# 898   2007    2012649    42.592   1569.331442                 Africa_Lesotho
# 886   2007    3921278    71.993  10461.058680                   Asia_Lebanon
# 874   2007    2505559    77.588  47306.989780                    Asia_Kuwait
# 862   2007   49044790    78.623  23348.139730               Asia_Korea, Rep.
# ...

# %%
gapminder_copy.sort_values(by='region', ascending=True)
# Out:
#       year       pop  life Exp     gdpPercap                     region
# 826   2007   6053193    72.535   4519.461171                Asia_Jordan
# 840   1957   9411381    54.081   1571.134655      Asia_Korea, Dem. Rep.
# 839   1952   8865488    50.056   1088.277758      Asia_Korea, Dem. Rep.
# 28    1962  11000948    48.303   2550.816880             Africa_Algeria
# 29    1967  12760499    51.407   3246.991771             Africa_Algeria
# 30    1972  14760787    54.518   4182.663766             Africa_Algeria
# 32    1977  17152804    58.014   4910.416756             Africa_Algeria
# 33    1982  20033753    61.368   5745.160213             Africa_Algeria
# 34    1987  23254956    65.799   5681.358539             Africa_Algeria
# 35    1992  26298373    67.744   5023.216647             Africa_Algeria
# 36    1997  29072015    69.152   4797.295051             Africa_Algeria
# 26    1952   9279525    43.077   2449.008185             Africa_Algeria
# ...

# %% [markdown]
# ### This section is about summarizing data

# %%
#mean population
gapminder_copy['pop'].mean()
# Out:
# 29542868.44100467

# %%
gapminder_copy[['region', 'pop']].groupby('region').mean()
# Out:
#                                                   pop
# region
#     Asia_Jordan                          6.053193e+06
#     Asia_Korea, Dem. Rep.                9.138434e+06
# Africa_Algeria                           1.987541e+07
# Africa_Angola                            7.309390e+06
# Africa_Benin                             4.017497e+06
# Africa_Botswana                          9.711862e+05
# Africa_Burkina Faso                      7.548677e+06
# Africa_Burundi                           4.740657e+06
# Africa_Cameroon                          9.816648e+06
# Africa_Central African Republic          2.497740e+06
# Africa_Central african republic          2.687409e+06
# Africa_Chad                              5.329256e+06
# Africa_Comoros                           3.616839e+05
# Africa_Congo, Dem. Rep.                  3.213732e+07
# Africa_Congo, Democratic Republic        4.779899e+07
# Africa_Congo, Rep.                       1.923209e+06
# ...

# %%
gapminder_copy[['region', 'year', 'pop']].groupby(['region', 'year']).mean()
# Out:
#                                      pop
# region                    year
#     Asia_Jordan           2007   6053193
#     Asia_Korea, Dem. Rep. 1952   8865488
#                           1957   9411381
# Africa_Algeria            1952   9279525
#                           1957  10270856
#                           1962  11000948
#                           1967  12760499
#                           1972  14760787
#                           1977  17152804
#                           1982  20033753
#                           1987  23254956
#                           1992  26298373
#                           1997  29072015
#                           2002  31287142
#                           2007  33333216
# Africa_Angola             1952   4232095
#                           1957   4561361
#                           1962   4826015
#                           1967   5247469
#                           1972   5894858
#                           1977   6162675
# ...

# %%
#who had the biggest increase in pop from 1952-2007?
#might exclude some countries missing those years
#for each country, take min and max year
#make a data frame that has region, population from min year, population from max year
#subtract first year from last year and divide by min year pop to figure out percent change, if you want to scale 
#sort in descending order
#Top is our answer
#tada, pseudocode

# %%
#Import plotting packages

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
plt.hist(gapminder_copy['life Exp'])
plt.xlabel('life_exp')
plt.ylabel('count')
# Out:
# Text(0,0.5,'count')

# %%
sns.boxplot(x = "year", y="life Exp", data = gapminder_copy)
plt.xlabel('year')
plt.ylabel('life expectancy')
# Out:
# Text(0,0.5,'life expectancy')

# %%
plt.scatter(gapminder_copy["gdpPercap"], gapminder_copy["life Exp"])
plt.xlabel('gdp per capita')
plt.ylabel('life expectancy')
# Out:
# Text(0,0.5,'life expectancy')

# %%
plt.scatter(gapminder_copy["gdpPercap"], gapminder_copy["life Exp"])
plt.xscale('log')
plt.xlabel('gdp per capita')
plt.ylabel('life expectancy')
plt.savefig('log_scatter.png')
